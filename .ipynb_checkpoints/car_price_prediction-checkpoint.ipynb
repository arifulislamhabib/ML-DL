# %%
import pandas as pd
import numpy as np

# %%
#Read data
df = pd.read_csv('/home/arif/Research/DataSets/car_price.csv')

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
#data standarization( Preprocessing):
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# ...

# %%
df.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# msrp                   int64
# dtype: object

# %%
df.dtypes == 'object'
# Out:
# make                  True
# model                 True
# year                 False
# engine_fuel_type      True
# engine_hp            False
# engine_cylinders     False
# transmission_type     True
# driven_wheels         True
# number_of_doors      False
# market_category       True
# vehicle_size          True
# vehicle_style         True
# highway_mpg          False
# city_mpg             False
# popularity           False
# msrp                 False
# dtype: bool

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# make                 object
# model                object
# engine_fuel_type     object
# transmission_type    object
# driven_wheels        object
# market_category      object
# vehicle_size         object
# vehicle_style        object
# dtype: object

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['make', 'model', 'engine_fuel_type', 'transmission_type',
#        'driven_wheels', 'market_category', 'vehicle_size', 'vehicle_style'],
#       dtype='object')

# %%
#index to a list
string = list(df.dtypes[df.dtypes == 'object'].index)

# %%
string
# Out:
# ['make',
#  'model',
#  'engine_fuel_type',
#  'transmission_type',
#  'driven_wheels',
#  'market_category',
#  'vehicle_size',
#  'vehicle_style']

# %%
for col in string:
    df[col] = df[col].str.lower().str.replace(' ','_')

# %%
df
# Out:
#           make       model  year                engine_fuel_type  engine_hp  \
# 0          bmw  1_series_m  2011     premium_unleaded_(required)      335.0
# 1          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 2          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 3          bmw    1_series  2011     premium_unleaded_(required)      230.0
# 4          bmw    1_series  2011     premium_unleaded_(required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11910    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11911    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11912    acura         zdx  2013  premium_unleaded_(recommended)      300.0
# 11913  lincoln      zephyr  2006                regular_unleaded      221.0
#
# ...

# %%
#EDA





#.....

# %%
df['make'].unique()[:5]
# Out:
# array(['bmw', 'audi', 'fiat', 'mercedes-benz', 'chrysler'], dtype=object)

# %%
df['make'].nunique()
# Out:
# 48

# %%
##Visualization:
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.histplot(df.msrp[df.msrp<100000], bins = 40)
# Out:
# <Axes: xlabel='msrp', ylabel='Count'>

# %%
###Validation Frame work:

# %%
# Train Test Split
len(df)
# Out:
# 11914

# %%
n = len(df)
n_val = int (n * 0.2)
n_test = int (n * 0.2)
n_train = n - n_val - n_test

# %%
n_val,n_test, n_train, n , n_val+n_train+n_test
# Out:
# (2382, 2382, 7150, 11914, 11914)

# %%
df_val
# Out:
#          make       model  year             engine_fuel_type  engine_hp  \
# 0         bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1         bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2         bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3         bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4         bmw    1_series  2011  premium_unleaded_(required)      230.0
# ...       ...         ...   ...                          ...        ...
# 2377  porsche     cayenne  2016  premium_unleaded_(required)      570.0
# 2378  porsche     cayenne  2016                       diesel      240.0
# 2379  porsche     cayenne  2017  premium_unleaded_(required)      520.0
# 2380  porsche     cayenne  2017  premium_unleaded_(required)      300.0
# 2381  porsche     cayenne  2017  premium_unleaded_(required)      440.0
#
#       engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# ...

# %%
df_test
# Out:
#          make     model  year                engine_fuel_type  engine_hp  \
# 2382  porsche   cayenne  2017     premium_unleaded_(required)      570.0
# 2383  porsche   cayenne  2017     premium_unleaded_(required)      420.0
# 2384  porsche  cayman_s  2006     premium_unleaded_(required)      295.0
# 2385  porsche    cayman  2014     premium_unleaded_(required)      275.0
# 2386  porsche    cayman  2014     premium_unleaded_(required)      325.0
# ...       ...       ...   ...                             ...        ...
# 4759     ford      flex  2016  premium_unleaded_(recommended)      365.0
# 4760     ford      flex  2016                regular_unleaded      287.0
# 4761     ford      flex  2016                regular_unleaded      287.0
# 4762     ford      flex  2016                regular_unleaded      287.0
# 4763     ford      flex  2016                regular_unleaded      287.0
#
#       engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# ...

# %%
idx = np.arange(n)
np.random.seed(42)
np.random.shuffle(idx)

# %%
df_val = df.iloc[idx[:n_val]]
df_test = df.iloc[idx[n_val : n_val + n_test]]
df_train = df.iloc[idx[n_val + n_test :]]

# %%
df_val
# Out:
#             make             model  year                engine_fuel_type  \
# 3995         gmc          envoy_xl  2005                regular_unleaded
# 7474  volkswagen            passat  2016                regular_unleaded
# 7300       honda           odyssey  2016                regular_unleaded
# 3148   chevrolet             cruze  2015                regular_unleaded
# 747        volvo               740  1991                regular_unleaded
# ...          ...               ...   ...                             ...
# 6914     lincoln               mkz  2017  premium_unleaded_(recommended)
# 267       nissan              350z  2007                regular_unleaded
# 4320        ford        expedition  2016                regular_unleaded
# 5799       acura               ilx  2015  premium_unleaded_(recommended)
# 6080  volkswagen  jetta_sportwagen  2014                regular_unleaded
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
len(y_train)
# Out:
# 7150

# %%
y_train = np.log1p(df_train.msrp.values)
y_test = np.log1p(df_test.msrp.values)
y_validation = np.log1p(df_val.msrp.values)

# %%
y_test
# Out:
# array([10.96302978, 10.88736216, 11.4494637 , ..., 10.62463893,
#        10.24991012, 11.11618717], shape=(2382,))

# %%
del df_train['msrp']
del df_test['msrp']
del df_val['msrp']

# %%
len(y_train)
# Out:
# 7150

# %%
len(df_train)
# Out:
# 7150

# %%
df_test
# Out:
#                 make         model  year  \
# 11511            bmw            x5  2015
# 3181        cadillac           ct6  2016
# 5357   mercedes-benz     gls-class  2017
# 4874             kia         forte  2016
# 8102           dodge       ram_250  1993
# ...              ...           ...   ...
# 6832      mitsubishi        mirage  2015
# 9814             kia       sorento  2015
# 4326            ford    expedition  2016
# 4044          suzuki       equator  2011
# 4137        cadillac  escalade_ext  2013
#
#                                    engine_fuel_type  engine_hp  \
# 11511                                        diesel      255.0
# 3181                 premium_unleaded_(recommended)      265.0
# 5357                    premium_unleaded_(required)      449.0
# 4874                               regular_unleaded      173.0
# 8102                               regular_unleaded      180.0
# ...                                             ...        ...
# ...

# %%
def train_linear_regression(X,y):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])

    XTX = X.T.dot(X)
    XTX_inv = np.linalg.inv(XTX)
    w_full = XTX_inv.dot(X.T).dot(y)
    return  w_full[0],w_full[1:]

# %%
## Car Price Predictoin Baseline model

# %%
df_train.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity'],
#       dtype='object')

# %%
base = ['engine_hp','engine_cylinders', 'highway_mpg', 'city_mpg', 'popularity']

# %%
X_train = df_train[base].values

# %%
X_train
# Out:
# array([[ 185.,    4.,   30.,   22., 2202.],
#        [ 240.,    6.,   29.,   20.,  873.],
#        [ 261.,    6.,   21.,   15., 2009.],
#        ...,
#        [ 220.,    4.,   33.,   25.,  873.],
#        [ 260.,    4.,   27.,   17.,  376.],
#        [ 235.,    4.,   28.,   21.,  454.]], shape=(7150, 5))

# %%
y_train
# Out:
# array([10.32944133, 10.9450179 , 10.39087053, ..., 10.22524491,
#        10.67523794, 10.48796319], shape=(7150,))

# %%
train_linear_regression(X_train, y_train)
# Out:
# (np.float64(nan), array([nan, nan, nan, nan, nan]))

# %%
df_train[base].isnull().sum()
# Out:
# engine_hp           37
# engine_cylinders    18
# highway_mpg          0
# city_mpg             0
# popularity           0
# dtype: int64

# %%
def rmse(y,y_pred):
    error = y - y_pred
    se = error ** 2
    mse = se.mean()
    return np.sqrt(mse)
